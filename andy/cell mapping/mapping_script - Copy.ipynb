# %% [markdown]
# ### Import statements

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ### Functions

# %%
def get_row_at_region(df, key):
    """ For use with count_df and region_df (cell_region_count.csv and region_counts.csv) """
    return df[df['region'] == key]

def get_row_at_parcellation_idx(df, idx):
    """ For use only with CCF_all_regions / 1_adult_mouse_brain_graph_mapping.csv """
    return df[df['parcellation_index'] == idx]

# Function to get all rows where a value is contained in a column with delimited values
def get_rows_containing_value_in_path(df, value, column_name='structure_id_path', delimiter='/'):
    pattern = f'(^|{delimiter}){value}({delimiter}|$)'
    pattern = re.escape(str(value))
    return df.loc[df[column_name].str.contains(pattern, regex=True)]

# %% [markdown]
# ### Load in data

# %%
# Our counted data
cell_count_df_path = "example files_b0039/cell_count.csv"
count_df_path = "example files_b0039/cell_region_count.csv"  # Count df just has the counts for the specific region
region_df_path = "example files_b0039/region_counts.csv"     # Region has the counts of all of levels combined



# Allen CCF provided data
ccf_all_regions_df_path = "../../CCF_DATA/1_adult_mouse_brain_graph_mapping.csv"
ccf_summary_structures_df_path = "../../CCF_DATA/300_summary_structures.csv"

# Read in the data
count_df = pd.read_csv(count_df_path)
region_df = pd.read_csv(region_df_path)
ccf_all_regions_df = pd.read_csv(ccf_all_regions_df_path)
ccf_summary_structures_df = pd.read_csv(ccf_summary_structures_df_path)

# Add an extra column to region_df for keeping track of ids
region_df['id'] = np.nan

# Fill in default values of CCF counts
ccf_all_regions_df['count'] = 0
ccf_summary_structures_df['count'] = 0

# %% [markdown]
# ### Visualize table data

# %%
count_df
# Out:
#      region  count                                region name level_0  \
# 0       987      4                                       root    root
# 1       595    212                 Taenia tecta, ventral part    root
# 2      1212      1                     Anterior area, layer 5    root
# 3       944      2            Primary auditory area, layer 6a    root
# 4       806      1             Primary auditory area, layer 4    root
# ..      ...    ...                                        ...     ...
# 126    1232      1                   Postrhinal area, layer 5    root
# 127     892      1        Posterolateral visual area, layer 5    root
# 128     600      1   Retrosplenial area, dorsal part, layer 5    root
# 129     677      1  Retrosplenial area, ventral part, layer 5    root
# 130      93      4                          subependymal zone    root
#
#                            level_1            level_2            level_3  \
# 0                              NaN                NaN                NaN
# 1    Basic cell groups and regions           Cerebrum    Cerebral cortex
# 2    Basic cell groups and regions           Cerebrum    Cerebral cortex
# 3    Basic cell groups and regions           Cerebrum    Cerebral cortex
# 4    Basic cell groups and regions           Cerebrum    Cerebral cortex
# ..                             ...                ...                ...
# 126  Basic cell groups and regions           Cerebrum    Cerebral cortex
# 127  Basic cell groups and regions           Cerebrum    Cerebral cortex
# 128  Basic cell groups and regions           Cerebrum    Cerebral cortex
# 129  Basic cell groups and regions           Cerebrum    Cerebral cortex
# 130            ventricular systems  lateral ventricle  subependymal zone
#
#             level_4          level_5                               level_6  \
# 0               NaN              NaN                                   NaN
# 1    Cortical plate  Olfactory areas                          Taenia tecta
# 2    Cortical plate        Isocortex  Posterior parietal association areas
# 3    Cortical plate        Isocortex                        Auditory areas
# 4    Cortical plate        Isocortex                        Auditory areas
# ..              ...              ...                                   ...
# 126  Cortical plate        Isocortex                          Visual areas
# 127  Cortical plate        Isocortex                          Visual areas
# 128  Cortical plate        Isocortex                    Retrosplenial area
# 129  Cortical plate        Isocortex                    Retrosplenial area
# 130             NaN              NaN                                   NaN
#
#                               level_7  \
# 0                                 NaN
# 1          Taenia tecta, ventral part
# 2                       Anterior area
# 3               Primary auditory area
# 4               Primary auditory area
# ..                                ...
# 126                   Postrhinal area
# 127        Posterolateral visual area
# 128   Retrosplenial area, dorsal part
# 129  Retrosplenial area, ventral part
# 130                               NaN
#
#                                        level_8 level_9  level_10
# 0                                          NaN     NaN       NaN
# 1                                          NaN     NaN       NaN
# 2                       Anterior area, layer 5     NaN       NaN
# 3              Primary auditory area, layer 6a     NaN       NaN
# 4               Primary auditory area, layer 4     NaN       NaN
# ..                                         ...     ...       ...
# 126                   Postrhinal area, layer 5     NaN       NaN
# 127        Posterolateral visual area, layer 5     NaN       NaN
# 128   Retrosplenial area, dorsal part, layer 5     NaN       NaN
# 129  Retrosplenial area, ventral part, layer 5     NaN       NaN
# 130                                        NaN     NaN       NaN
#
# [131 rows x 14 columns]

# %%
region_df
# Out:
#     level_0                        level_1                          level_2  \
# 0      root                            NaN                              NaN
# 1      root  Basic cell groups and regions                       Brain stem
# 2      root  Basic cell groups and regions                       Brain stem
# 3      root  Basic cell groups and regions                       Brain stem
# 4      root  Basic cell groups and regions                       Brain stem
# ..      ...                            ...                              ...
# 126    root                   fiber tracts  lateral forebrain bundle system
# 127    root                   fiber tracts   medial forebrain bundle system
# 128    root                   fiber tracts   medial forebrain bundle system
# 129    root            ventricular systems                lateral ventricle
# 130    root            ventricular systems                lateral ventricle
#
#                level_3                            level_4  \
# 0                  NaN                                NaN
# 1            Hindbrain                            Medulla
# 2            Hindbrain                               Pons
# 3            Hindbrain                               Pons
# 4           Interbrain                       Hypothalamus
# ..                 ...                                ...
# 126    corpus callosum  corpus callosum, anterior forceps
# 127   cerebrum related                      fornix system
# 128   cerebrum related                      fornix system
# 129                NaN                                NaN
# 130  subependymal zone                                NaN
#
#                             level_5                         level_6 level_7  \
# 0                               NaN                             NaN     NaN
# 1          Medulla, sensory related   Nucleus of the solitary tract     NaN
# 2    Pons, behavioral state related  Superior central nucleus raphe     NaN
# 3               Pons, motor related     Tegmental reticular nucleus     NaN
# 4                               NaN                             NaN     NaN
# ..                              ...                             ...     ...
# 126                             NaN                             NaN     NaN
# 127                          alveus                             NaN     NaN
# 128                         fimbria                             NaN     NaN
# 129                             NaN                             NaN     NaN
# 130                             NaN                             NaN     NaN
#
#     level_8 level_9  level_10  region  count  \
# 0       NaN     NaN       NaN     987   6825
# 1       NaN     NaN       NaN     641      1
# 2       NaN     NaN       NaN     669      1
# 3       NaN     NaN       NaN     564      1
# 4       NaN     NaN       NaN    1086      3
# ..      ...     ...       ...     ...    ...
# 126     NaN     NaN       NaN     946      3
# 127     NaN     NaN       NaN     456      1
# 128     NaN     NaN       NaN     593      1
# 129     NaN     NaN       NaN      76     10
# 130     NaN     NaN       NaN      93      4
#
#                            region name  id
# 0                                 root NaN
# 1        Nucleus of the solitary tract NaN
# 2       Superior central nucleus raphe NaN
# 3          Tegmental reticular nucleus NaN
# 4                         Hypothalamus NaN
# ..                                 ...  ..
# 126  corpus callosum, anterior forceps NaN
# 127                             alveus NaN
# 128                            fimbria NaN
# 129                  lateral ventricle NaN
# 130                  subependymal zone NaN
#
# [131 rows x 15 columns]

# %%
ccf_all_regions_df
# Out:
#              id acronym color_hex_triplet                           name  \
# 0           997    root            FFFFFF                           root
# 1             8    grey            BFDAE3  Basic cell groups and regions
# 2           567      CH            B0F0FF                       Cerebrum
# 3           688     CTX            B0FFB8                Cerebral cortex
# 4           695   CTXpl            70FF70                 Cortical plate
# ...         ...     ...               ...                            ...
# 1322         49     ipf            AAAAAA     intraparafloccular fissure
# 1323         57     pms            AAAAAA              paramedian sulcus
# 1324         65     pfs            AAAAAA           parafloccular sulcus
# 1325        624     IPF            AAAAAA          Interpeduncular fossa
# 1326  304325711  retina            7F2E7E                         retina
#
#       graph_order  parent_structure_id    structure_id_path  \
# 0               0                   -1                /997/
# 1               1                  997              /997/8/
# 2               2                    8          /997/8/567/
# 3               3                  567      /997/8/567/688/
# 4               4                  688  /997/8/567/688/695/
# ...           ...                  ...                  ...
# 1322         1322                 1040   /997/1024/1040/49/
# 1323         1323                 1040   /997/1024/1040/57/
# 1324         1324                 1040   /997/1024/1040/65/
# 1325         1325                 1024       /997/1024/624/
# 1326         1326                  997      /997/304325711/
#
#       parcellation_index  count
# 0                    987      0
# 1                      7      0
# 2                    557      0
# 3                    678      0
# 4                    685      0
# ...                  ...    ...
# 1322                  44      0
# 1323                  52      0
# 1324                  60      0
# 1325                 614      0
# 1326                1207      0
#
# [1327 rows x 9 columns]

# %%
ccf_summary_structures_df
# Out:
#            acronym                                      name  \
# 0              FRP             Frontal pole, cerebral cortex
# 1              MOp                        Primary motor area
# 2              MOs                      Secondary motor area
# 3            SSp-n          Primary somatosensory area, nose
# 4          SSp-bfd  Primary somatosensory area, barrel field
# ..             ...                                       ...
# 366  VL-unassigned             lateral ventricle, unassigned
# 367  V3-unassigned               third ventricle, unassigned
# 368             AQ                         cerebral aqueduct
# 369  V4-unassigned              fourth ventricle, unassigned
# 370              c        central canal, spinal cord/medulla
#
#     color_hex_triplet  graph_order identifier  red  green  blue  \
# 0             #268F45          6.0    MBA:184   38    143    69
# 1             #1F9D5A         18.0    MBA:985   31    157    90
# 2             #1F9D5A         24.0    MBA:993   31    157    90
# 3             #188064         44.0    MBA:353   24    128   100
# 4             #188064         51.0    MBA:329   24    128   100
# ..                ...          ...        ...  ...    ...   ...
# 366           #AAAAAA       1293.3     MBA:81  170    170   170
# 367           #AAAAAA       1299.3    MBA:129  170    170   170
# 368           #AAAAAA       1300.3    MBA:140  170    170   170
# 369           #AAAAAA       1301.3    MBA:145  170    170   170
# 370           #AAAAAA       1303.3    MBA:164  170    170   170
#
#     parent_identifier  count
# 0             MBA:315      0
# 1             MBA:500      0
# 2             MBA:500      0
# 3             MBA:322      0
# 4             MBA:322      0
# ..                ...    ...
# 366               NaN      0
# 367               NaN      0
# 368               NaN      0
# 369               NaN      0
# 370               NaN      0
#
# [371 rows x 10 columns]

# %% [markdown]
# ### Work with counted cells

# %%
import numpy as np
import pandas as pd
import re
import sys


def get_row_at_region(df, key):
    """ For use with count_df and region_df (cell_region_count.csv and region_counts.csv) """
    return df[df['region'] == key]

def get_row_at_parcellation_idx(df, idx):
    """ For use only with CCF_all_regions / 1_adult_mouse_brain_graph_mapping.csv """
    return df[df['parcellation_index'] == idx]

# Function to get all rows where a value is contained in a column with delimited values
def get_rows_containing_value_in_path(df, value, column_name='structure_id_path', delimiter='/'):
    pattern = f'(^|{delimiter}){value}({delimiter}|$)'
    pattern = re.escape(str(value))
    return df.loc[df[column_name].str.contains(pattern, regex=True)]


# Our counted data
count_df_path = "example files_b0039/cell_region_count.csv"  # Count df just has the counts for the specific region
region_df_path = "example files_b0039/region_counts.csv"     # Region has the counts of all of levels combined

# Allen CCF provided data
ccf_all_regions_df_path = "../../CCF_DATA/1_adult_mouse_brain_graph_mapping.csv"
ccf_summary_structures_df_path = "../../CCF_DATA/300_summary_structures.csv"

# Read in the data
count_df = pd.read_csv(count_df_path)
region_df = pd.read_csv(region_df_path)
ccf_all_regions_df = pd.read_csv(ccf_all_regions_df_path)
ccf_summary_structures_df = pd.read_csv(ccf_summary_structures_df_path)

# Add an extra column to region_df for keeping track of ids
region_df['id'] = np.nan

# Fill in default values of CCF counts
ccf_all_regions_df['count'] = 0
ccf_summary_structures_df['count'] = 0

################################


# Goal: convert info in region_counts.csv to 300 summary regions
region_df
ccf_summary_structures_df

# Find the ids for each row in region_df
for index, row in region_df.iterrows():
    # Use the region id and find the corresponding row in 1_adult_mouse_brain_graph_mapping.csv by matching with the parcellation_index
    ccf_all_regions_row = get_row_at_parcellation_idx(ccf_all_regions_df, row['region'])
    # Save the id to region_df (region_counts.csv)
    region_df.at[index, 'id'] = ccf_all_regions_row.iloc[0]['id']
    
    # Add the counts to summary structures
    ccf_summary_structures_df
    
region_df['id'] = region_df['id'].astype(int)

# Now add the counts of region_df to the summary structures (300_summary_structures.csv)
for index, row in region_df.iterrows():
    curr_id = row['id']
    # Add the count to the summary structures based on the identifier column
    identifier = "MBA:" + str(curr_id)
    #print(identifier)
    curr_summary_structures_row = ccf_summary_structures_df[ccf_summary_structures_df['identifier'] == identifier]
    if not curr_summary_structures_row.empty:  # Add if the identifier is found in the summary structures
        curr_summary_structures_row.at[curr_summary_structures_row.index[0], 'count'] = row['count']
    #else:
    #    print("\tNot found in summary structures")
        
        
############################################

# However, some regions in region_count cannot be found in summary structures because the region level is smaller than the 300 structures we want. 
# We need to figure out for this region (dentate gyrus, granule cell layer, region number/parcellation_index 622, id=632 is the lower level region of which regions inside 300 

# we need to first go over each row inside 300 summary regions.csv, based on the id number, check the column 
# structure_id_path in 1_adult_mouse_brain_graph_mapping_all_reigons.csv
for index, row in ccf_summary_structures_df.iterrows():
    
    if row['identifier'] is not np.nan:
        curr_identifier = int(row['identifier'].replace("MBA:", ""))  # Remove the MBA: string
    #print(curr_identifier)
    
    all_region_rows = get_rows_containing_value_in_path(ccf_all_regions_df, curr_identifier)
    parcellation_indices = all_region_rows['parcellation_index'].tolist()
    #print(parcellation_indices)
    
    total_count = 0
    for p in parcellation_indices:
        region_df_row = get_row_at_region(region_df, p)
        if not region_df_row.empty:
            total_count += int(region_df_row['count'].iloc[0])
    #print(total_count)

    # Save count to row
    curr_count = ccf_summary_structures_df.at[index, 'count']
    if curr_count != total_count and curr_count != 0:
        print("Problem with ", ccf_summary_structures_df['name'][index])
        print("\tCurrent count:", curr_count)
        print("\tTotal count:", total_count)
    else:
        ccf_summary_structures_df.at[index, 'count'] = total_count
    
    #curr_structure_id_path = ccf_all_regions_df[ccf_all_regions_df['id'] == curr_id].iloc[0]['structure_id_path']
    #print(curr_structure_id_path)
    #if curr_structure_id_path == "4000":
    #    print("Found it")
    #    print(row)
    #    break

ccf_summary_structures_df.to_csv('updated_summary_structures.csv', index=False)

# %%
ccf_summary_structures_df
# Out:
#            acronym                                      name  \
# 0              FRP             Frontal pole, cerebral cortex
# 1              MOp                        Primary motor area
# 2              MOs                      Secondary motor area
# 3            SSp-n          Primary somatosensory area, nose
# 4          SSp-bfd  Primary somatosensory area, barrel field
# ..             ...                                       ...
# 366  VL-unassigned             lateral ventricle, unassigned
# 367  V3-unassigned               third ventricle, unassigned
# 368             AQ                         cerebral aqueduct
# 369  V4-unassigned              fourth ventricle, unassigned
# 370              c        central canal, spinal cord/medulla
#
#     color_hex_triplet  graph_order identifier  red  green  blue  \
# 0             #268F45          6.0    MBA:184   38    143    69
# 1             #1F9D5A         18.0    MBA:985   31    157    90
# 2             #1F9D5A         24.0    MBA:993   31    157    90
# 3             #188064         44.0    MBA:353   24    128   100
# 4             #188064         51.0    MBA:329   24    128   100
# ..                ...          ...        ...  ...    ...   ...
# 366           #AAAAAA       1293.3     MBA:81  170    170   170
# 367           #AAAAAA       1299.3    MBA:129  170    170   170
# 368           #AAAAAA       1300.3    MBA:140  170    170   170
# 369           #AAAAAA       1301.3    MBA:145  170    170   170
# 370           #AAAAAA       1303.3    MBA:164  170    170   170
#
#     parent_identifier  count
# 0             MBA:315      4
# 1             MBA:500      0
# 2             MBA:500      3
# 3             MBA:322      1
# 4             MBA:322     13
# ..                ...    ...
# 366               NaN     62
# 367               NaN      6
# 368               NaN      0
# 369               NaN      0
# 370               NaN      0
#
# [371 rows x 10 columns]

# %%
# Out:
# 184
# [177, 63, 657, 1288, 1289, 1290]
# 4
# Problem with index 0
# 985
# [975, 310, 933, 638, 834, 872]
# 0
# 993
# [983, 646, 952, 757, 1010, 1074]
# 3
# Problem with index 2
# 353
# [343, 548, 828, 644, 692, 879, 919]
# 1
# Problem with index 3
# 329
# [319, 971, 194, 1036, 1059, 1027, 1051, 1235, 1236, 1237, 1238, 1239, 1240, 1241]
# 13
# Problem with index 4
# 337
# [327, 1019, 108, 1083, 1115, 468, 500]
# 0
# 345
# [335, 868, 647, 940, 964, 1091, 2]
# 2
# Problem with index 6
# 369
# [359, 440, 844, 567, 615, 935, 1015]
# 0
# 361
# [351, 996, 660, 1075, 1100, 8, 451]
# 0
# 182305689
# [1200, 1201, 1202, 1203, 1204, 1205, 1206]
# 2
# Problem with index 9
# 378
# [368, 863, 796, 1024, 1079, 852, 883]
# 9
# Problem with index 10
# 1057
# [1046, 32, 173, 143, 180, 628, 652]
# 0
# 677
# [667, 887, 1095, 1000, 1047, 847, 839]
# 2
# Problem with index 12
# 1011
# [1001, 517, 590, 668, 245, 151, 236, 1242, 1243, 1244, 1245, 1246, 1247, 1248]
# 16
# Problem with index 13
# 1002
# [992, 725, 244, 806, 837, 944, 995]
# 16
# Problem with index 14
# 1027
# [1016, 686, 633, 749, 781, 242, 446]
# 3
# Problem with index 15
# 1018
# [1007, 949, 745, 980, 1012, 510, 588]
# 5
# Problem with index 16
# 402
# [392, 1063, 895, 1103, 226, 591, 639]
# 4
# Problem with index 17
# 394
# [384, 272, 1055, 391, 423, 1035, 431]
# 2
# Problem with index 18
# 409
# [399, 411, 963, 563, 603, 69, 116]
# 3
# Problem with index 19
# 385
# [375, 583, 811, 711, 768, 29, 295]
# 5
# Problem with index 20
# 425
# [415, 740, 261, 859, 892, 367, 383]
# 1
# Problem with index 21
# 533
# [523, 795, 36, 491, 555, 250, 459]
# 1
# Problem with index 22
# 312782574
# [1215, 1216, 1217, 1218, 1219, 1220, 1221]
# 0
# 312782628
# [1228, 1229, 1230, 1231, 1232, 1233, 1234]
# 1
# Problem with index 24
# 39
# [35, 925, 204, 1004, 909, 917]
# 2
# Problem with index 25
# 48
# [43, 578, 286, 762, 800, 809]
# 6
# Problem with index 26
# 972
# [962, 166, 188, 294, 353, 79, 127]
# 62
# Problem with index 27
# 44
# [39, 697, 737, 546, 817, 1043, 1070]
# 72
# Problem with index 28
# 723
# [713, 438, 402, 620, 430, 478]
# 864
# Problem with index 29
# 731
# [721, 474, 514, 572, 610, 900, 1291]
# 419
# Problem with index 30
# 746
# [736, 959, 278, 1112, 598, 670]
# 899
# Problem with index 31
# 104
# [99, 986, 318, 1090, 773, 821]
# 12
# Problem with index 32
# 111
# [106, 115, 158, 334, 304, 345]
# 0
# 119
# [114, 694, 684, 790, 665, 689]
# 46
# Problem with index 34
# 894
# [884, 661, 955, 764, 896, 270, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269]
# 4
# Problem with index 35
# 879
# [869, 432, 424, 535, 600, 265, 320]
# 2
# Problem with index 36
# 886
# [876, 532, 596, 420, 677, 580, 612]
# 1
# Problem with index 37
# 312782546
# [1208, 1209, 1210, 1211, 1212, 1213, 1214]
# 2
# Problem with index 38
# 417
# [407, 1222, 1223, 1224, 1225, 1226, 1227]
# 4
# Problem with index 39
# 541
# [531, 92, 1114, 227, 279, 719, 776]
# 1
# Problem with index 40
# 922
# [912, 530, 878, 682, 325, 358]
# 6
# Problem with index 41
# 895
# [885, 826, 417, 978, 967, 1034]
# 3
# Problem with index 42
# 507
# [497, 205, 213, 221, 229, 237]
# 48
# Problem with index 43
# 151
# [146, 181, 189, 197]
# 0
# 159
# [154, 162, 169, 176, 184, 192, 155, 163]
# 120
# Problem with index 45
# 589
# [579, 587, 287, 1023, 1031, 1039, 1048, 595, 296, 1056, 1064, 1071]
# 343
# Problem with index 46
# 814
# [804, 486, 525, 350, 636, 259]
# 46
# Problem with index 47
# 961
# [951, 147, 267, 274, 281]
# 7
# Problem with index 48
# 619
# [609, 382, 253, 260, 1120]
# 0
# 639
# [629, 185, 193, 201]
# 0
# 647
# [637, 645, 574, 366, 209, 217, 225, 653, 582, 373, 233, 241, 249]
# 0
# 788
# [778, 390, 398, 406, 414]
# 0
# 566
# [556, 507, 1121, 1122, 1123]
# 0
# 382
# [372, 381, 389, 397, 405]
# 1810
# <ipython-input-80-ea5f7bf14e6d>:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return df.loc[df[column_name].str.contains(pattern)]
# <ipython-input-87-0719a109a3bd>:20: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   total_count += int(region_df_row['count'])
# Problem with index 54
# 423
# [413, 421, 428, 436, 444]
# 225
# Problem with index 55
# 463
# [453, 461, 469, 476, 485, 494]
# 476
# Problem with index 56
# 726
# [716, 1159, 1160, 622, 1158, 724, 732, 741, 748, 756, 765, 772, 780, 789, 797, 805, 813]
# 95
# Problem with index 57
# 982
# [972]
# 0
# 19
# [17]
# 15
# Problem with index 59
# 918
# [908, 1109, 18, 989, 705, 754, 47, 87, 302, 134, 377, 25, 55]
# 8
# Problem with index 60
# 926
# [916, 516, 533, 458, 498, 654, 702, 717, 540, 733]
# 22
# Problem with index 61
# 843
# [833, 1149, 1150, 1151]
# 4
# Problem with index 62
# 1037
# [1026, 1152, 1153, 1154]
# 13
# Problem with index 63
# 1084
# [1073, 1155, 1156, 1157]
# 1
# Problem with index 64
# 502
# [492, 499, 819, 835, 827, 508, 843, 860, 851]
# 21
# Problem with index 65
# 484682470
# [1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278]
# 41
# Problem with index 66
# 589508447
# [1308]
# 0
# 484682508
# [1279]
# 1
# Problem with index 68
# 583
# [573]
# 0
# 952
# [942]
# 0
# 966
# [956]
# 0
# 131
# [126]
# 0
# 295
# [285, 293, 301, 441]
# 0
# 319
# [309, 317, 324]
# 0
# 780
# [770]
# 0
# 672
# [662]
# 5
# Problem with index 76
# 56
# [51]
# 3
# Problem with index 77
# 998
# [988]
# 0
# 754
# [744, 471, 479, 139, 448, 455, 463]
# 38
# Problem with index 79
# 250
# [243]
# 0
# 258
# [251]
# 2
# Problem with index 81
# 266
# [258]
# 0
# 310
# [300]
# 0
# 333
# [323]
# 0
# 23
# [21]
# 0
# 292
# [282]
# 0
# 536
# [526, 534, 541, 549]
# 0
# 1105
# [1094]
# 0
# 403
# [393, 401, 408, 416, 462, 470, 477, 425]
# 0
# 1022
# [1011]
# 0
# 1031
# [1020]
# 0
# 342
# [332]
# 0
# 298
# [288]
# 0
# 564
# [554]
# 3
# Problem with index 94
# 596
# [586]
# 31
# Problem with index 95
# 581
# [571]
# 0
# 351
# [341, 349, 527, 488, 495, 503, 536, 511, 544, 552, 519, 357, 559, 568, 575, 584, 592]
# 0
# 912
# [902, 1163, 1162, 1161]
# 0
# 920
# [910, 966, 1166, 1165, 1164, 974, 1169, 1168, 1167]
# 3
# Problem with index 298
# 928
# [918, 982, 1172, 1171, 1170, 991, 1175, 1174, 1173, 1080, 1178, 1177, 1176]
# 4
# Problem with index 299
# 936
# [926, 1181, 1180, 1179]
# 1
# Problem with index 300
# 944
# [934, 1184, 1183, 1182]
# 0
# 951
# [941, 1187, 1186, 1185]
# 0
# 957
# [947, 1190, 1189, 1188]
# 0
# 968
# [958, 1193, 1192, 1191]
# 2
# Problem with index 304
# 1007
# [997, 1130, 1129, 1128]
# 0
# 1017
# [1006, 1045, 1133, 1132, 1131, 1053, 1136, 1135, 1134]
# 1
# Problem with index 306
# 1025
# [1014, 1139, 1138, 1137]
# 0
# 1033
# [1022, 1142, 1141, 1140]
# 0
# 1041
# [1030, 1145, 1144, 1143]
# 1
# Problem with index 309
# 1049
# [1038, 1148, 1147, 1146]
# 0
# 989
# [979]
# 0
# 91
# [86]
# 0
# 846
# [836]
# 0
# 589508455
# [1310]
# 0
# 885
# [875]
# 0
# 949
# [939]
# 0
# 840
# [830, 1005, 19, 655, 528, 449, 890]
# 14
# Problem with index 317
# 848
# [838, 866, 906, 326, 112, 120, 347]
# 0
# 832
# [822, 57, 153]
# 0
# 911
# [901, 374]
# 0
# 710
# [700]
# 0
# 901
# [891, 88, 222, 695, 784]
# 0
# 798
# [788, 1117, 1104]
# 0
# 933
# [923, 1065, 403, 938, 831, 631, 496, 648, 623, 472]
# 0
# 808
# [798]
# 0
# 917
# [907, 230]
# 0
# 717
# [707]
# 0
# 813
# [803]
# 0
# 925
# [915]
# 0
# 792
# [782, 922, 560, 512, 848, 576, 504, 370, 378, 386, 687]
# 0
# 871
# [861, 26, 379, 238, 254, 262, 283, 268, 246, 275, 617]
# 0
# 744
# [734]
# 0
# 752
# [742, 316, 802, 80, 840, 856, 73, 1110, 543, 489, 640, 480, 394, 400, 363]
# 0
# 728
# [718]
# 1
# Problem with index 334
# 776
# [766, 946, 569, 954, 1097, 961, 969, 1281, 976]
# 3
# Problem with index 335
# 784
# [774, 5, 914, 1025, 1002, 993, 984, 183, 191, 1008, 1017]
# 0
# 896
# [886, 1081, 12, 81, 355, 1282, 1283]
# 0
# 760
# [750, 137, 97, 104, 129, 299, 307]
# 0
# 877
# [867, 1040, 1049, 1032]
# 0
# 863
# [853, 387, 214]
# 0
# 736
# [726]
# 0
# 855
# [845, 198, 206]
# 0
# 941
# [931]
# 0
# 768
# [758, 874, 882, 898, 930, 1088, 456, 520, 593, 735, 410, 727, 418, 426, 608, 433, 439, 703, 464, 33, 291, 1284]
# 2
# Problem with index 344
# 824
# [814, 49, 395, 168, 339, 807, 815, 823, 161, 331, 175, 752, 760, 769, 777, 145, 41, 743, 680, 671, 663, 1057, 712, 1072, 792, 585, 601, 720, 65, 537, 553]
# 0
# 89
# [84]
# 0
# 98
# [93]
# 4
# Problem with index 347
# 108
# [103]
# 0
# 116
# [111]
# 0
# 153
# [148]
# 12
# Problem with index 363
# 1009
# [999, 957, 875, 939, 830, 1005, 19, 655, 528, 449, 890, 838, 866, 906, 326, 112, 120, 347, 822, 57, 153, 901, 374, 700, 891, 88, 222, 695, 784, 788, 1117, 1104, 923, 1065, 403, 938, 831, 631, 496, 648, 623, 472, 798, 907, 230, 707, 803, 915, 782, 922, 560, 512, 848, 576, 504, 370, 378, 386, 687, 861, 26, 379, 238, 254, 262, 283, 268, 246, 275, 617, 950, 734, 742, 316, 802, 80, 840, 856, 73, 1110, 543, 489, 640, 480, 394, 400, 363, 718, 1280, 973, 766, 946, 569, 954, 1097, 961, 969, 1281, 976, 774, 5, 914, 1025, 1002, 993, 984, 183, 191, 1008, 1017, 886, 1081, 12, 81, 355, 1282, 1283, 990, 750, 137, 97, 104, 129, 299, 307, 867, 1040, 1049, 1032, 853, 387, 214, 726, 845, 198, 206, 931, 981, 758, 874, 882, 898, 930, 1088, 456, 520, 593, 735, 410, 727, 418, 426, 608, 433, 439, 703, 464, 33, 291, 1284, 814, 49, 395, 168, 339, 807, 815, 823, 161, 331, 175, 752, 760, 769, 777, 145, 41, 743, 680, 671, 663, 1057, 712, 1072, 792, 585, 601, 720, 65, 537, 553]
# 42
# Problem with index 364
# 484682512
# [1280]
# 0
# 81
# [76, 84, 93, 103, 111]
# 14
# Problem with index 366
# 129
# [124]
# 0
# 140
# [135]
# 0
# 145
# [140, 148]
# 0
# 164
# [159]
# 0
#            acronym                                      name  \
# 0              FRP             Frontal pole, cerebral cortex
# 1              MOp                        Primary motor area
# 2              MOs                      Secondary motor area
# 3            SSp-n          Primary somatosensory area, nose
# 4          SSp-bfd  Primary somatosensory area, barrel field
# ..             ...                                       ...
# 366  VL-unassigned             lateral ventricle, unassigned
# 367  V3-unassigned               third ventricle, unassigned
# 368             AQ                         cerebral aqueduct
# 369  V4-unassigned              fourth ventricle, unassigned
# 370              c        central canal, spinal cord/medulla
#
#     color_hex_triplet  graph_order identifier  red  green  blue  \
# 0             #268F45          6.0    MBA:184   38    143    69
# 1             #1F9D5A         18.0    MBA:985   31    157    90
# 2             #1F9D5A         24.0    MBA:993   31    157    90
# 3             #188064         44.0    MBA:353   24    128   100
# 4             #188064         51.0    MBA:329   24    128   100
# ..                ...          ...        ...  ...    ...   ...
# 366           #AAAAAA       1293.3     MBA:81  170    170   170
# 367           #AAAAAA       1299.3    MBA:129  170    170   170
# 368           #AAAAAA       1300.3    MBA:140  170    170   170
# 369           #AAAAAA       1301.3    MBA:145  170    170   170
# 370           #AAAAAA       1303.3    MBA:164  170    170   170
#
#     parent_identifier  count
# 0             MBA:315      0
# 1             MBA:500      0
# 2             MBA:500      0
# 3             MBA:322      0
# 4             MBA:322      0
# ..                ...    ...
# 366               NaN      0
# 367               NaN      0
# 368               NaN      0
# 369               NaN      0
# 370               NaN      0
#
# [371 rows x 10 columns]

# %%
ccf_all_regions_df
# Out:
#              id acronym color_hex_triplet                           name  \
# 0           997    root            FFFFFF                           root
# 1             8    grey            BFDAE3  Basic cell groups and regions
# 2           567      CH            B0F0FF                       Cerebrum
# 3           688     CTX            B0FFB8                Cerebral cortex
# 4           695   CTXpl            70FF70                 Cortical plate
# ...         ...     ...               ...                            ...
# 1322         49     ipf            AAAAAA     intraparafloccular fissure
# 1323         57     pms            AAAAAA              paramedian sulcus
# 1324         65     pfs            AAAAAA           parafloccular sulcus
# 1325        624     IPF            AAAAAA          Interpeduncular fossa
# 1326  304325711  retina            7F2E7E                         retina
#
#       graph_order  parent_structure_id    structure_id_path  \
# 0               0                   -1                /997/
# 1               1                  997              /997/8/
# 2               2                    8          /997/8/567/
# 3               3                  567      /997/8/567/688/
# 4               4                  688  /997/8/567/688/695/
# ...           ...                  ...                  ...
# 1322         1322                 1040   /997/1024/1040/49/
# 1323         1323                 1040   /997/1024/1040/57/
# 1324         1324                 1040   /997/1024/1040/65/
# 1325         1325                 1024       /997/1024/624/
# 1326         1326                  997      /997/304325711/
#
#       parcellation_index  count
# 0                    987      0
# 1                      7      0
# 2                    557      0
# 3                    678      0
# 4                    685      0
# ...                  ...    ...
# 1322                  44      0
# 1323                  52      0
# 1324                  60      0
# 1325                 614      0
# 1326                1207      0
#
# [1327 rows x 9 columns]

# %%
idx = 595
get_row_at_region(count_df, idx)
# Out:
#    region  count                 region name level_0  \
# 1     595    212  Taenia tecta, ventral part    root
#
#                          level_1   level_2          level_3         level_4  \
# 1  Basic cell groups and regions  Cerebrum  Cerebral cortex  Cortical plate
#
#            level_5       level_6                     level_7 level_8 level_9  \
# 1  Olfactory areas  Taenia tecta  Taenia tecta, ventral part     NaN     NaN
#
#    level_10
# 1       NaN

# %%
get_row_at_region(region_df, idx)
# Out:
#     level_0                        level_1   level_2          level_3  \
# 113    root  Basic cell groups and regions  Cerebrum  Cerebral cortex
#
#             level_4          level_5       level_6  \
# 113  Cortical plate  Olfactory areas  Taenia tecta
#
#                         level_7 level_8 level_9  level_10  region  count  \
# 113  Taenia tecta, ventral part     NaN     NaN       NaN     595    212
#
#                     region name
# 113  Taenia tecta, ventral part

# %%
# Region has the counts of all of levels combined
row = region_df[region_df['region name'] == 'Medulla']
print(row)
print()

# Count df just has the counts for the specific region
row = count_df[count_df['region name'] == 'Medulla']
row

row = count_df[count_df['region name'] == 'root']
row
# Out:
#   level_0                        level_1     level_2    level_3  level_4  \
# 1    root  Basic cell groups and regions  Brain stem  Hindbrain  Medulla
#
#   level_5 level_6 level_7 level_8 level_9  level_10  region  count region name
# 1     NaN     NaN     NaN     NaN     NaN       NaN     344     15     Medulla
#    region  count region name level_0 level_1 level_2 level_3 level_4 level_5  \
# 0     987      8        root    root     NaN     NaN     NaN     NaN     NaN
#
#   level_6 level_7 level_8 level_9  level_10
# 0     NaN     NaN     NaN     NaN       NaN

# %%
row = region_df[region_df['region name'] == 'lateral ventricle']
row
# Out:
#     level_0              level_1            level_2 level_3 level_4 level_5  \
# 149    root  ventricular systems  lateral ventricle     NaN     NaN     NaN
#
#     level_6 level_7 level_8 level_9  level_10  region  count  \
# 149     NaN     NaN     NaN     NaN       NaN      76     15
#
#            region name
# 149  lateral ventricle

# %%
row = region_df[region_df['region name'] == 'lateral ventricle']
row
# Lateral ventricle region counts = 15

# Lateral ventricle individual count = 9 
row = count_df[count_df['region name'] == 'lateral ventricle']
row

# Ventricular system count = 0
row = count_df[count_df['region name'] == 'ventricular systems']
row

# Root count = 8
row = count_df[count_df['region name'] == 'root']
row
# Out:
#    region  count region name level_0 level_1 level_2 level_3 level_4 level_5  \
# 0     987      8        root    root     NaN     NaN     NaN     NaN     NaN
#
#   level_6 level_7 level_8 level_9  level_10
# 0     NaN     NaN     NaN     NaN       NaN

# %%
region_df
# Out:
#     level_0                        level_1                          level_2  \
# 0      root                            NaN                              NaN
# 1      root  Basic cell groups and regions                       Brain stem
# 2      root  Basic cell groups and regions                       Brain stem
# 3      root  Basic cell groups and regions                       Brain stem
# 4      root  Basic cell groups and regions                       Brain stem
# ..      ...                            ...                              ...
# 147    root                   fiber tracts  lateral forebrain bundle system
# 148    root                   fiber tracts   medial forebrain bundle system
# 149    root            ventricular systems                lateral ventricle
# 150    root            ventricular systems                lateral ventricle
# 151    root            ventricular systems                lateral ventricle
#
#                level_3                            level_4  \
# 0                  NaN                                NaN
# 1            Hindbrain                            Medulla
# 2            Hindbrain                            Medulla
# 3            Hindbrain                            Medulla
# 4            Hindbrain                            Medulla
# ..                 ...                                ...
# 147    corpus callosum  corpus callosum, anterior forceps
# 148   cerebrum related                      fornix system
# 149                NaN                                NaN
# 150     choroid plexus                                NaN
# 151  subependymal zone                                NaN
#
#                       level_5  \
# 0                         NaN
# 1                         NaN
# 2      Medulla, motor related
# 3    Medulla, sensory related
# 4    Medulla, sensory related
# ..                        ...
# 147                       NaN
# 148    postcommissural fornix
# 149                       NaN
# 150                       NaN
# 151                       NaN
#
#                                                level_6  \
# 0                                                  NaN
# 1                                                  NaN
# 2                            Lateral reticular nucleus
# 3                        Nucleus of the solitary tract
# 4    Spinal nucleus of the trigeminal, interpolar part
# ..                                                 ...
# 147                                                NaN
# 148                              columns of the fornix
# 149                                                NaN
# 150                                                NaN
# 151                                                NaN
#
#                                            level_7 level_8 level_9  level_10  \
# 0                                              NaN     NaN     NaN       NaN
# 1                                              NaN     NaN     NaN       NaN
# 2    Lateral reticular nucleus, magnocellular part     NaN     NaN       NaN
# 3                                              NaN     NaN     NaN       NaN
# 4                                              NaN     NaN     NaN       NaN
# ..                                             ...     ...     ...       ...
# 147                                            NaN     NaN     NaN       NaN
# 148                                            NaN     NaN     NaN       NaN
# 149                                            NaN     NaN     NaN       NaN
# 150                                            NaN     NaN     NaN       NaN
# 151                                            NaN     NaN     NaN       NaN
#
#      region  count                                        region name
# 0       987  11752                                               root
# 1       344     15                                            Medulla
# 2       945      4      Lateral reticular nucleus, magnocellular part
# 3       641      3                      Nucleus of the solitary tract
# 4       427      1  Spinal nucleus of the trigeminal, interpolar part
# ..      ...    ...                                                ...
# 147     946      3                  corpus callosum, anterior forceps
# 148     426      5                              columns of the fornix
# 149      76     15                                  lateral ventricle
# 150     103      1                                     choroid plexus
# 151      93      5                                  subependymal zone
#
# [152 rows x 14 columns]

# %%
count_df
# Out:
#      region  count                                        region name level_0  \
# 0       987      8                                               root    root
# 1       144      1            Paraventricular nucleus of the thalamus    root
# 2       539      1                                           Thalamus    root
# 3       970      1                       Dorsal premammillary nucleus    root
# 4      1316     10             Medial mammillary nucleus, dorsal part    root
# ..      ...    ...                                                ...     ...
# 147     971     13  Primary somatosensory area, barrel field, layer 1    root
# 148     796      2         Supplemental somatosensory area, layer 2/3    root
# 149     986     24       Agranular insular area, dorsal part, layer 1    root
# 150     294      4                          Prelimbic area, layer 2/3    root
# 151      76      9                                  lateral ventricle    root
#
#                            level_1            level_2          level_3  \
# 0                              NaN                NaN              NaN
# 1    Basic cell groups and regions         Brain stem       Interbrain
# 2    Basic cell groups and regions         Brain stem       Interbrain
# 3    Basic cell groups and regions         Brain stem       Interbrain
# 4    Basic cell groups and regions         Brain stem       Interbrain
# ..                             ...                ...              ...
# 147  Basic cell groups and regions           Cerebrum  Cerebral cortex
# 148  Basic cell groups and regions           Cerebrum  Cerebral cortex
# 149  Basic cell groups and regions           Cerebrum  Cerebral cortex
# 150  Basic cell groups and regions           Cerebrum  Cerebral cortex
# 151            ventricular systems  lateral ventricle              NaN
#
#             level_4                                         level_5  \
# 0               NaN                                             NaN
# 1          Thalamus  Thalamus, polymodal association cortex related
# 2          Thalamus                                             NaN
# 3      Hypothalamus                        Hypothalamic medial zone
# 4      Hypothalamus                        Hypothalamic medial zone
# ..              ...                                             ...
# 147  Cortical plate                                       Isocortex
# 148  Cortical plate                                       Isocortex
# 149  Cortical plate                                       Isocortex
# 150  Cortical plate                                       Isocortex
# 151             NaN                                             NaN
#
#                                   level_6  \
# 0                                     NaN
# 1    Midline group of the dorsal thalamus
# 2                                     NaN
# 3            Dorsal premammillary nucleus
# 4                         Mammillary body
# ..                                    ...
# 147                   Somatosensory areas
# 148                   Somatosensory areas
# 149                Agranular insular area
# 150                        Prelimbic area
# 151                                   NaN
#
#                                      level_7  \
# 0                                        NaN
# 1    Paraventricular nucleus of the thalamus
# 2                                        NaN
# 3                                        NaN
# 4                  Medial mammillary nucleus
# ..                                       ...
# 147               Primary somatosensory area
# 148          Supplemental somatosensory area
# 149      Agranular insular area, dorsal part
# 150                Prelimbic area, layer 2/3
# 151                                      NaN
#
#                                           level_8  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4          Medial mammillary nucleus, dorsal part
# ..                                            ...
# 147      Primary somatosensory area, barrel field
# 148    Supplemental somatosensory area, layer 2/3
# 149  Agranular insular area, dorsal part, layer 1
# 150                                           NaN
# 151                                           NaN
#
#                                                level_9  level_10
# 0                                                  NaN       NaN
# 1                                                  NaN       NaN
# 2                                                  NaN       NaN
# 3                                                  NaN       NaN
# 4                                                  NaN       NaN
# ..                                                 ...       ...
# 147  Primary somatosensory area, barrel field, layer 1       NaN
# 148                                                NaN       NaN
# 149                                                NaN       NaN
# 150                                                NaN       NaN
# 151                                                NaN       NaN
#
# [152 rows x 14 columns]

# %% [markdown]
# ## Output dataframes

# %%
ccf_all_regions_df
# Out:
#              id acronym color_hex_triplet                           name  \
# 0           997    root            FFFFFF                           root
# 1             8    grey            BFDAE3  Basic cell groups and regions
# 2           567      CH            B0F0FF                       Cerebrum
# 3           688     CTX            B0FFB8                Cerebral cortex
# 4           695   CTXpl            70FF70                 Cortical plate
# ...         ...     ...               ...                            ...
# 1322         49     ipf            AAAAAA     intraparafloccular fissure
# 1323         57     pms            AAAAAA              paramedian sulcus
# 1324         65     pfs            AAAAAA           parafloccular sulcus
# 1325        624     IPF            AAAAAA          Interpeduncular fossa
# 1326  304325711  retina            7F2E7E                         retina
#
#       graph_order  parent_structure_id    structure_id_path  \
# 0               0                   -1                /997/
# 1               1                  997              /997/8/
# 2               2                    8          /997/8/567/
# 3               3                  567      /997/8/567/688/
# 4               4                  688  /997/8/567/688/695/
# ...           ...                  ...                  ...
# 1322         1322                 1040   /997/1024/1040/49/
# 1323         1323                 1040   /997/1024/1040/57/
# 1324         1324                 1040   /997/1024/1040/65/
# 1325         1325                 1024       /997/1024/624/
# 1326         1326                  997      /997/304325711/
#
#       parcellation_index  counting_number
# 0                    987                0
# 1                      7                0
# 2                    557                0
# 3                    678                0
# 4                    685                0
# ...                  ...              ...
# 1322                  44                0
# 1323                  52                0
# 1324                  60                0
# 1325                 614                0
# 1326                1207                0
#
# [1327 rows x 9 columns]

# %%
ccf_summary_structures_df
# Out:
#            acronym                                      name  \
# 0              FRP             Frontal pole, cerebral cortex
# 1              MOp                        Primary motor area
# 2              MOs                      Secondary motor area
# 3            SSp-n          Primary somatosensory area, nose
# 4          SSp-bfd  Primary somatosensory area, barrel field
# ..             ...                                       ...
# 366  VL-unassigned             lateral ventricle, unassigned
# 367  V3-unassigned               third ventricle, unassigned
# 368             AQ                         cerebral aqueduct
# 369  V4-unassigned              fourth ventricle, unassigned
# 370              c        central canal, spinal cord/medulla
#
#     color_hex_triplet  graph_order identifier  red  green  blue  \
# 0             #268F45          6.0    MBA:184   38    143    69
# 1             #1F9D5A         18.0    MBA:985   31    157    90
# 2             #1F9D5A         24.0    MBA:993   31    157    90
# 3             #188064         44.0    MBA:353   24    128   100
# 4             #188064         51.0    MBA:329   24    128   100
# ..                ...          ...        ...  ...    ...   ...
# 366           #AAAAAA       1293.3     MBA:81  170    170   170
# 367           #AAAAAA       1299.3    MBA:129  170    170   170
# 368           #AAAAAA       1300.3    MBA:140  170    170   170
# 369           #AAAAAA       1301.3    MBA:145  170    170   170
# 370           #AAAAAA       1303.3    MBA:164  170    170   170
#
#     parent_identifier  counting_number
# 0             MBA:315                0
# 1             MBA:500                0
# 2             MBA:500                0
# 3             MBA:322                0
# 4             MBA:322                0
# ..                ...              ...
# 366               NaN                0
# 367               NaN                0
# 368               NaN                0
# 369               NaN                0
# 370               NaN                0
#
# [371 rows x 10 columns]
