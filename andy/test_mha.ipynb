# %%
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
fp = "G://Downloads//result_image.mha"
img = sitk.ReadImage(fp)
arr = sitk.GetArrayFromImage(img)
type(arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(arr, cmap='gray')
plt.axis(False)
plt.show()
